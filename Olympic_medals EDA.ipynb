# %% [markdown]
# # **Olympic Medal data from 1976 to 2008**

# %% [markdown]
# **Importing the Libraries & data for processing**

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data =pd.read_csv('Summer-Olympic-medals.csv',encoding='latin-1')
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15433 entries, 0 to 15432
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   City          15316 non-null  object
#  1   Year          15316 non-null  float64
#  2   Sport         15316 non-null  object
#  3   Discipline    15316 non-null  object
#  4   Event         15316 non-null  object
#  5   Athlete       15316 non-null  object
#  6   Gender        15316 non-null  object
#  7   Country_Code  15316 non-null  object
#  8   Country       15316 non-null  object
#  9   Event_gender  15316 non-null  object
#  10  Medal         15316 non-null  object
# dtypes: float64(1), object(10)
# memory usage: 1.3+ MB

# %%
print (data.shape)
print (data.isnull().sum())
# Out:
# (15433, 11)
# City            117
# Year            117
# Sport           117
# Discipline      117
# Event           117
# Athlete         117
# Gender          117
# Country_Code    117
# Country         117
# Event_gender    117
# Medal           117
# dtype: int64

# %%
print(data.nunique())
# Out:
# City                9
# Year                9
# Sport              28
# Discipline         41
# Event             293
# Athlete         11337
# Gender              2
# Country_Code      128
# Country           127
# Event_gender        3
# Medal               3
# dtype: int64

# %%
print(data.head())
# Out:
#        City    Year     Sport Discipline           Event  \
# 0  Montreal  1976.0  Aquatics     Diving  3m springboard
# 1  Montreal  1976.0  Aquatics     Diving  3m springboard
# 2  Montreal  1976.0  Aquatics     Diving  3m springboard
# 3  Montreal  1976.0  Aquatics     Diving  3m springboard
# 4  Montreal  1976.0  Aquatics     Diving    10m platform
#
#                     Athlete Gender Country_Code        Country Event_gender  \
# 0           KÖHLER, Christa  Women          GDR   East Germany            W
# 1       KOSENKOV, Aleksandr    Men          URS   Soviet Union            M
# 2      BOGGS, Philip George    Men          USA  United States            M
# 3  CAGNOTTO, Giorgio Franco    Men          ITA          Italy            M
# 4    WILSON, Deborah Keplar  Women          USA  United States            W
#
#     Medal
# 0  Silver
# 1  Bronze
# 2    Gold
# 3  Silver
# 4  Bronze

# %%
print(data.columns)
# Out:
# Index(['City', 'Year', 'Sport', 'Discipline', 'Event', 'Athlete', 'Gender',
#        'Country_Code', 'Country', 'Event_gender', 'Medal'],
#       dtype='object')

# %% [markdown]
# **Exploring the data using visualization**

# %%
data['Medal'].value_counts()
# Out:
# Bronze    5258
# Gold      5042
# Silver    5016
# Name: Medal, dtype: int64

# %%
data.groupby('Gender')['Medal'].count()
# Out:
# Gender
# Men      9388
# Women    5928
# Name: Medal, dtype: int64

# %%
plt.figure(figsize=(2,4))
sns.countplot(data['Gender'])

# %% [markdown]
# *Dividing the Medal Count based on GENDER, overall medals achieved by Men are high*

# %%
data.groupby('Gender')['Medal'].value_counts()
# Out:
# Gender  Medal
# Men     Bronze    3257
#         Gold      3080
#         Silver    3051
# Women   Bronze    2001
#         Silver    1965
#         Gold      1962
# Name: Medal, dtype: int64

# %%
plt.figure(figsize=(6,6))
sns.countplot(x='Gender', hue = 'Medal', data = data)

# %% [markdown]
# *Divinding the target variable to different classes based on GENDER*

# %%
data.groupby('Year')['Medal'].count().sort_values(ascending= True)
# Out:
# Year
# 1976.0    1305
# 1980.0    1387
# 1984.0    1459
# 1988.0    1546
# 1992.0    1705
# 1996.0    1859
# 2004.0    1998
# 2000.0    2015
# 2008.0    2042
# Name: Medal, dtype: int64

# %%
plt.figure(figsize=(10,6))
sns.countplot(x='Year', data= data)

# %% [markdown]
# *Total Medals achieved at Olympic games and the count is keep increasing*

# %%
data.groupby('Gender')['Year'].value_counts()
# Out:
# Gender  Year
# Men     2000.0    1126
#         2008.0    1110
#         1992.0    1105
#         2004.0    1099
#         1996.0    1082
#         1988.0    1011
#         1984.0     973
#         1980.0     958
#         1976.0     924
# Women   2008.0     932
#         2004.0     899
#         2000.0     889
#         1996.0     777
#         1992.0     600
#         1988.0     535
#         1984.0     486
#         1980.0     429
#         1976.0     381
# Name: Year, dtype: int64

# %%
plt.figure(figsize= (15,6))
sns.countplot(x='Year', hue = 'Gender', data = data)

# %% [markdown]
# *Segregating the Medals count depending on YEAR & GENDER variables. Men are acheiving more medals duirng the tenure and we can also see that Women's count is increasing rapidly*

# %%
plt.figure(figsize= (15,6))
sns.countplot(x='Year', hue = 'Medal', data = data)

# %% [markdown]
# *Visualizing the data on the bases of Different classes in Target variable during the occurance at each olympic games.*
# *Trend on all the different classes(Gold, Silver and Bronze Models) are increasing every year*

# %%
data.groupby('Country')['Medal'].count().sort_values(ascending=False)[:20]
# Out:
# Country
# United States     1992
# Soviet Union      1021
# Australia          798
# Germany            691
# China              679
# Russia             638
# East Germany       626
# Italy              486
# Romania            482
# United Kingdom     467
# Korea, South       454
# France             449
# Netherlands        428
# Japan              388
# Hungary            368
# Cuba               349
# West Germany       345
# Spain              328
# Brazil             318
# Canada             304
# Name: Medal, dtype: int64

# %%
plt.figure(figsize=(15,6))
chart = sns.countplot(x = 'Country', data = data, order = data['Country'].value_counts().index[:20])
chart.set_xticklabels(chart.get_xticklabels(), rotation=45, horizontalalignment='right')
# Out:
# [Text(0, 0, 'United States'),
#  Text(0, 0, 'Soviet Union'),
#  Text(0, 0, 'Australia'),
#  Text(0, 0, 'Germany'),
#  Text(0, 0, 'China'),
#  Text(0, 0, 'Russia'),
#  Text(0, 0, 'East Germany'),
#  Text(0, 0, 'Italy'),
#  Text(0, 0, 'Romania'),
#  Text(0, 0, 'United Kingdom'),
#  Text(0, 0, 'Korea, South'),
#  Text(0, 0, 'France'),
#  Text(0, 0, 'Netherlands'),
#  Text(0, 0, 'Japan'),
#  Text(0, 0, 'Hungary'),
#  Text(0, 0, 'Cuba'),
#  Text(0, 0, 'West Germany'),
#  Text(0, 0, 'Spain'),
#  Text(0, 0, 'Brazil'),
#  Text(0, 0, 'Canada')]

# %% [markdown]
# *Visualizing the data with respect to Medals achieved by each country, listed are the top 20 contributors
# who achieved the different medals during the Olympic Games.*

# %%
plt.figure(figsize=(15,6))
chart = sns.countplot(x = 'Country', hue= 'Medal', data = data, order = data['Country'].value_counts().index[:20])
chart.set_xticklabels(chart.get_xticklabels(), rotation=45, horizontalalignment='right')
# Out:
# [Text(0, 0, 'United States'),
#  Text(0, 0, 'Soviet Union'),
#  Text(0, 0, 'Australia'),
#  Text(0, 0, 'Germany'),
#  Text(0, 0, 'China'),
#  Text(0, 0, 'Russia'),
#  Text(0, 0, 'East Germany'),
#  Text(0, 0, 'Italy'),
#  Text(0, 0, 'Romania'),
#  Text(0, 0, 'United Kingdom'),
#  Text(0, 0, 'Korea, South'),
#  Text(0, 0, 'France'),
#  Text(0, 0, 'Netherlands'),
#  Text(0, 0, 'Japan'),
#  Text(0, 0, 'Hungary'),
#  Text(0, 0, 'Cuba'),
#  Text(0, 0, 'West Germany'),
#  Text(0, 0, 'Spain'),
#  Text(0, 0, 'Brazil'),
#  Text(0, 0, 'Canada')]

# %% [markdown]
# *Different classes of Target variable representation in regards with Country's Achievement*

# %%
data.groupby('Sport')['Medal'].count().sort_values(ascending = False)
# Out:
# Sport
# Aquatics             2210
# Athletics            1523
# Rowing               1377
# Hockey                817
# Gymnastics            783
# Handball              780
# Volleyball            695
# Canoe / Kayak         672
# Football              669
# Basketball            646
# Fencing               606
# Wrestling             533
# Cycling               483
# Equestrian            423
# Sailing               417
# Boxing                416
# Judo                  396
# Shooting              345
# Baseball              335
# Weightlifting         311
# Softball              180
# Archery               162
# Badminton             120
# Table Tennis          120
# Tennis                118
# Modern Pentathlon      81
# Taekwondo              80
# Triathlon              18
# Name: Medal, dtype: int64

# %%
plt.figure(figsize=(15,6))
chart =sns.countplot(x='Sport',data=data, order = data['Sport'].value_counts().index[:25])
chart.set_xticklabels(chart.get_xticklabels(), rotation=45)
# Out:
# [Text(0, 0, 'Aquatics'),
#  Text(0, 0, 'Athletics'),
#  Text(0, 0, 'Rowing'),
#  Text(0, 0, 'Hockey'),
#  Text(0, 0, 'Gymnastics'),
#  Text(0, 0, 'Handball'),
#  Text(0, 0, 'Volleyball'),
#  Text(0, 0, 'Canoe / Kayak'),
#  Text(0, 0, 'Football'),
#  Text(0, 0, 'Basketball'),
#  Text(0, 0, 'Fencing'),
#  Text(0, 0, 'Wrestling'),
#  Text(0, 0, 'Cycling'),
#  Text(0, 0, 'Equestrian'),
#  Text(0, 0, 'Sailing'),
#  Text(0, 0, 'Boxing'),
#  Text(0, 0, 'Judo'),
#  Text(0, 0, 'Shooting'),
#  Text(0, 0, 'Baseball'),
#  Text(0, 0, 'Weightlifting'),
#  Text(0, 0, 'Softball'),
#  Text(0, 0, 'Archery'),
#  Text(0, 0, 'Table Tennis'),
#  Text(0, 0, 'Badminton'),
#  Text(0, 0, 'Tennis')]

# %% [markdown]
# *Differentiating the data in regards with sports played during the Olympic Games where Aquatics sports hold most of medals during the Games.*

# %%
data.groupby('Sport')['Medal'].value_counts()
# Out:
# Sport          Medal
# Aquatics       Gold      757
#                Silver    736
#                Bronze    717
# Archery        Bronze     54
#                Gold       54
#                         ...
# Weightlifting  Silver    104
#                Bronze    103
# Wrestling      Bronze    189
#                Gold      172
#                Silver    172
# Name: Medal, Length: 84, dtype: int64

# %%
plt.figure(figsize= (15,6))
chart= sns.countplot(x ='Sport', hue= 'Medal',data = data, order = data['Sport'].value_counts().index)
chart.set_xticklabels(chart.get_xticklabels(), rotation=90)
# Out:
# [Text(0, 0, 'Aquatics'),
#  Text(0, 0, 'Athletics'),
#  Text(0, 0, 'Rowing'),
#  Text(0, 0, 'Hockey'),
#  Text(0, 0, 'Gymnastics'),
#  Text(0, 0, 'Handball'),
#  Text(0, 0, 'Volleyball'),
#  Text(0, 0, 'Canoe / Kayak'),
#  Text(0, 0, 'Football'),
#  Text(0, 0, 'Basketball'),
#  Text(0, 0, 'Fencing'),
#  Text(0, 0, 'Wrestling'),
#  Text(0, 0, 'Cycling'),
#  Text(0, 0, 'Equestrian'),
#  Text(0, 0, 'Sailing'),
#  Text(0, 0, 'Boxing'),
#  Text(0, 0, 'Judo'),
#  Text(0, 0, 'Shooting'),
#  Text(0, 0, 'Baseball'),
#  Text(0, 0, 'Weightlifting'),
#  Text(0, 0, 'Softball'),
#  Text(0, 0, 'Archery'),
#  Text(0, 0, 'Table Tennis'),
#  Text(0, 0, 'Badminton'),
#  Text(0, 0, 'Tennis'),
#  Text(0, 0, 'Modern Pentathlon'),
#  Text(0, 0, 'Taekwondo'),
#  Text(0, 0, 'Triathlon')]

# %%
country_medalcount = data.groupby(['Year','Country'])['Medal'].count().reset_index()
#print(country_medalcount)
country_medalcount.sort_values(by='Year')
l =list(country_medalcount.Country.unique())
ratio = []
for i in list(country_medalcount.Country.unique()):
    x = country_medalcount[country_medalcount["Country"] == i]
    #print (x)
    medals = sum(x.Medal)/len(x)
    #print(medals)
    ratio.append(medals)

medal_ratio = pd.DataFrame({"country": l,
    "ratio": ratio})

#print (medal_ratio)
medal_ratio = medal_ratio.sort_values(by= 'ratio', ascending = False)

# %%
plt.figure(figsize = (10,10))
sns.barplot( y = 'country', x = 'ratio', data = medal_ratio[:20])

# %% [markdown]
# *For example, having 500 medals when you participated 2 times is not the same if you have participated 5 times. Ratio would be totally different. Above Graph gives us the value which informs on how many medals received and how many times Country participated in the Olympic Game.*

# %%
data1 = pd.get_dummies(data, columns = ['Medal'])
country_list = list(data1['Country'].unique())
#print(country_list)
medal_gold = []
medal_silver = []
medal_bronze = []
ratio_gold = []
ratio_silver = []
ratio_bronze = []
for i in country_list:
    x = data1[data1["Country"] == i]
    #print('---------------------------')
    #print(x.shape)
    gold = x.Medal_Gold.sum()
    medal_gold.append(gold)
    ratio_gold.append((gold)/len(x))
    #ratio_gold = ratio_gold.append(sum(x.Medal_Gold)/len(x))
    silver = x.Medal_Silver.sum()
    medal_silver.append(silver)
    ratio_silver.append(silver/len(x))
    bronze = x.Medal_Bronze.sum()
    medal_bronze.append(bronze)
    ratio_bronze.append(bronze/len(x))

medal_list = pd.DataFrame({"country": country_list,"medal_gold": medal_gold, 'medal_silver': medal_silver,'medal_bronze': medal_bronze}) 
medal_list['medal_total'] = medal_list.medal_gold + medal_list.medal_silver + medal_list.medal_bronze
medal_list = medal_list.sort_values(by="medal_total", ascending=False)
print (medal_list[:20])

ratio_list = pd.DataFrame({"country": country_list,"Ratio_gold_medal": ratio_gold, 'ratio_silver_medal': ratio_silver,
    'ratio_bronze_medal': ratio_bronze})

sorted_ratio_list = ratio_list[:20].sort_values(by= "Ratio_gold_medal", ascending = False)
# Out:
# <ipython-input-26-c6abd9162e0b>:16: RuntimeWarning: invalid value encountered in longlong_scalars
#   ratio_gold.append((gold)/len(x))
# <ipython-input-26-c6abd9162e0b>:20: RuntimeWarning: invalid value encountered in longlong_scalars
#   ratio_silver.append(silver/len(x))
# <ipython-input-26-c6abd9162e0b>:23: RuntimeWarning: invalid value encountered in longlong_scalars
#   ratio_bronze.append(bronze/len(x))
#            country  medal_gold  medal_silver  medal_bronze  medal_total
# 2    United States         928           583           481         1992
# 1     Soviet Union         439           285           297         1021
# 5        Australia         216           270           312          798
# 78         Germany         237           176           278          691
# 51           China         234           252           193          679
# 92          Russia         192           206           240          638
# ...

# %% [markdown]
# *Above value represents the count of different medals each country received and its total count.*

# %%
plt.figure(figsize=(15,3))
plt.xticks(rotation=90)

sns.lineplot(data = sorted_ratio_list[:20], x = 'country', y = 'Ratio_gold_medal')
sns.lineplot(data = sorted_ratio_list[:20], x = 'country', y = 'ratio_silver_medal')
sns.lineplot(data = sorted_ratio_list[:20], x = 'country', y = 'ratio_bronze_medal')
plt.legend(["Silver", 'Gold', 'Bronze'])
    
#chart= sns.countplot(x ='Sport', hue= 'Medal',data = data, order = data['Sport'].value_counts().index)
#chart.set_xticklabels(chart.get_xticklabels(), rotation=90)    
#chart.set_xticklabels(chart.get_xticklabels(), rotation = 90)
#sns.lineplot(ratio_list['Ratio_silver_medal'])
#sns.lineplot(ratio_list['Ratio_gold_medal'])

# %% [markdown]
# *Representing the trend of Gold, Bronze and Silver Medals with respect to top Countries*
